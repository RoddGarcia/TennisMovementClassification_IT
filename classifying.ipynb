# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp

# modelo_nome = 'modelo_tenis_multiclasse_braços.h5'
modelo_nome = 'modelo_tenis_multiclasse_v2.h5'

# %% [markdown]
# ## Carregar modelo treinado

# %%
#Carregar modelo
model = tf.keras.models.load_model(modelo_nome)

#Inicia MediaPipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

landmarks_seq = []

video_path = "./videos_teste/fh_teste.mov"
cap = cv2.VideoCapture(video_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# !['KeyPoints HPE'](KeyPoints_HPE.jpg)

# %% [markdown]
# ## Usar um vídeo como referência

# %%
BRAÇO_LANDMARKS = [11, 12, 13, 14, 15, 16]

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(frame_rgb)

    if results.pose_landmarks:
        frame_landmarks = []
        
        #Captura apenas os 6 pontos dos braços
        for i in BRAÇO_LANDMARKS:
            lm = results.pose_landmarks.landmark[i]
            frame_landmarks.extend([lm.x, lm.y, lm.z])

        landmarks_seq.append(frame_landmarks)

cap.release()

#Padroniza para X frames
janela = 30
num_features = 18  #Apenas os pontos dos braços (6 landmarks x 3 coordenadas)

if len(landmarks_seq) < janela:
    padding = [[0] * num_features] * (janela - len(landmarks_seq))  #Garante o formato correto (1, 30, 18)
    landmarks_seq = padding + landmarks_seq
else:
    landmarks_seq = landmarks_seq[-janela:]

#Agora a entrada sempre terá (1, 30, 18)
X_input = np.array([landmarks_seq])

print(f"Shape de X_input antes da predição: {X_input.shape}")

#Fazer a previsão corretamente
predictions = model.predict(X_input)[0]  #Obtém as probabilidades das 3 classes

#Obtém a classe com maior probabilidade
classe_predita = np.argmax(predictions)
labels = ["Forehand", "Backhand", "Nenhum"]
movimento = labels[classe_predita]  #Converte índice para nome da classe

print(f"Forehand: {predictions[0]:.4f} \nBackhand: {predictions[1]:.4f} \nNenhum: {predictions[2]:.4f}")
print(f"Movimento detectado: {movimento}")
# Out:
# Shape de X_input antes da predição: (1, 30, 18)
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B73E1C99E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B73E1C99E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Movimento detectado: Forehand
# Probabilidades -> Forehand: 0.9977 | Backhand: 0.0021 | Nenhum: 0.0002

# %% [markdown]
# ## Teste em tempo real

# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
import time
from collections import deque

#Abrir câmera em tempo real
cap = cv2.VideoCapture(0)
#Para arrumar o FPS da câmera
camera_fps = 30

mp_drawing = mp.solutions.drawing_utils

cap.set(cv2.CAP_PROP_FPS, camera_fps)

#Cache que armazena os últimos X frames
frames_cache = 30
landmarks_seq = deque(maxlen=frames_cache)  

labels = ["Forehand", "Backhand", "Nenhum"]

braco_landmarks = [11, 12, 13, 14, 15, 16]

#Variáveis que controlam o título
movimento_atual = "Nenhum"
ultima_classificacao = time.time()
cor_movimento = (0, 255, 0)

#Contadores de movimentos
forehand_count = 0
backhand_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(frame_rgb)

    if results.pose_landmarks:
        #Para extrair somente os landmarks dos braços
        frame_landmarks = []
        for i in braco_landmarks:
            lm = results.pose_landmarks.landmark[i]
            frame_landmarks.extend([lm.x, lm.y, lm.z])

        #Adicionar os landmarks ao buffer (mantém apenas os últimos X frames)
        landmarks_seq.append(frame_landmarks)

        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

    #Faz a previsão constantemente
    if len(landmarks_seq) >= 30:  #Verifica a cada X frames
        X_input = np.array([list(landmarks_seq)[-30:]])  #Últimos 30 frames

        # Fazer a previsão
        predictions = model.predict(X_input)[0]  #Obtém as 3 probabilidades
        classe_predita = np.argmax(predictions)  #Obtém a classe com maior probabilidade
        confianca = predictions[classe_predita]  #Obtém a confiança da previsão

        #Aplicar um limiar de confiança para evitar previsões erradas
        if confianca < 0.5:
            movimento = "Nenhum"
        else:
            movimento = labels[classe_predita]

        #Se o movimento for Forehand ou Backhand, segurar o título por 1 segundo
        if movimento in ["Forehand", "Backhand"]:
            if movimento != movimento_atual:
                movimento_atual = movimento
                ultima_classificacao = time.time()
                cor_movimento = (255, 0, 0)  # Azul durante 1 segundo

                #Aumenta o contador correspondente
                if movimento == "Forehand":
                    forehand_count += 1
                elif movimento == "Backhand":
                    backhand_count += 1

        #Se já passou 1 segundo desde a última classificação, voltar para verde
        if time.time() - ultima_classificacao > 1:
            cor_movimento = (0, 255, 0)  # Verde novamente

        #Exibir o resultado na tela
        cv2.putText(frame, f"Movimento: {movimento_atual}", (50, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, cor_movimento, 2)

        #Exibir as probabilidades no console (para depuração)
        print(f"Forehand: {predictions[0]:.4f} | Backhand: {predictions[1]:.4f} | Nenhum: {predictions[2]:.4f}")

        pred_forehand = predictions[0] * 100
        pred_backhand = predictions[1] * 100

        cv2.putText(frame, f"Forehand: {(pred_forehand):.2f}%",
                    (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, cor_movimento, 2)
        cv2.putText(frame, f"Backhand: {(pred_backhand):.2f}%",
                    (50, 150), cv2.FONT_HERSHEY_SIMPLEX, 1, cor_movimento, 2)
        # cv2.putText(frame, f"Nenhum: {predictions[2]:.4f}",
        #             (50, 200), cv2.FONT_HERSHEY_SIMPLEX, 1, cor_movimento, 2)

        #Exibir contadores de movimentos na tela
        cv2.putText(frame, f"Forehand : {forehand_count}", (50, 250),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        cv2.putText(frame, f"Backhand : {backhand_count}", (50, 300),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    cv2.imshow("Detecção em Tempo Real", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):  #Reduz delay para capturar mais frames
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0026 | Backhand: 0.1034 | Nenhum: 0.8940
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Forehand: 0.0026 | Backhand: 0.1033 | Nenhum: 0.8941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0026 | Backhand: 0.1032 | Nenhum: 0.8941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Forehand: 0.0026 | Backhand: 0.1028 | Nenhum: 0.8946
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.1022 | Nenhum: 0.8951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0027 | Backhand: 0.1019 | Nenhum: 0.8953
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Forehand: 0.0027 | Backhand: 0.1005 | Nenhum: 0.8968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Forehand: 0.0027 | Backhand: 0.0985 | Nenhum: 0.8987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Forehand: 0.0028 | Backhand: 0.0966 | Nenhum: 0.9006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Forehand: 0.0029 | Backhand: 0.0949 | Nenhum: 0.9023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Forehand: 0.0030 | Backhand: 0.0927 | Nenhum: 0.9044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0031 | Backhand: 0.0903 | Nenhum: 0.9066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0032 | Backhand: 0.0880 | Nenhum: 0.9088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Forehand: 0.0033 | Backhand: 0.0856 | Nenhum: 0.9111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0023 | Backhand: 0.1114 | Nenhum: 0.8863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0023 | Backhand: 0.1108 | Nenhum: 0.8869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0023 | Backhand: 0.1103 | Nenhum: 0.8874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0023 | Backhand: 0.1098 | Nenhum: 0.8879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0024 | Backhand: 0.1093 | Nenhum: 0.8883
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0024 | Backhand: 0.1088 | Nenhum: 0.8889
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0024 | Backhand: 0.1082 | Nenhum: 0.8895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0024 | Backhand: 0.1073 | Nenhum: 0.8903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0024 | Backhand: 0.1065 | Nenhum: 0.8911
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Forehand: 0.0025 | Backhand: 0.1056 | Nenhum: 0.8919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0025 | Backhand: 0.1046 | Nenhum: 0.8929
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Forehand: 0.0025 | Backhand: 0.1035 | Nenhum: 0.8940
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0025 | Backhand: 0.1025 | Nenhum: 0.8950
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0026 | Backhand: 0.1015 | Nenhum: 0.8959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0026 | Backhand: 0.1006 | Nenhum: 0.8968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0026 | Backhand: 0.0999 | Nenhum: 0.8975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0027 | Backhand: 0.0993 | Nenhum: 0.8980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0027 | Backhand: 0.0986 | Nenhum: 0.8987
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0028 | Backhand: 0.0977 | Nenhum: 0.8995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0028 | Backhand: 0.0968 | Nenhum: 0.9003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0029 | Backhand: 0.0959 | Nenhum: 0.9012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0030 | Backhand: 0.0953 | Nenhum: 0.9017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0030 | Backhand: 0.0949 | Nenhum: 0.9021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0030 | Backhand: 0.0949 | Nenhum: 0.9021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0030 | Backhand: 0.0951 | Nenhum: 0.9019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0030 | Backhand: 0.0962 | Nenhum: 0.9008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0029 | Backhand: 0.0977 | Nenhum: 0.8994
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0029 | Backhand: 0.0998 | Nenhum: 0.8973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0028 | Backhand: 0.1018 | Nenhum: 0.8953
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0028 | Backhand: 0.1034 | Nenhum: 0.8938
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0028 | Backhand: 0.1050 | Nenhum: 0.8922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.1064 | Nenhum: 0.8909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0027 | Backhand: 0.1075 | Nenhum: 0.8897
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0027 | Backhand: 0.1086 | Nenhum: 0.8887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Forehand: 0.0027 | Backhand: 0.1095 | Nenhum: 0.8878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0027 | Backhand: 0.1103 | Nenhum: 0.8870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0027 | Backhand: 0.1110 | Nenhum: 0.8864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Forehand: 0.0026 | Backhand: 0.1115 | Nenhum: 0.8859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Forehand: 0.0026 | Backhand: 0.1120 | Nenhum: 0.8854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Forehand: 0.0026 | Backhand: 0.1120 | Nenhum: 0.8854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0026 | Backhand: 0.1119 | Nenhum: 0.8856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0026 | Backhand: 0.1117 | Nenhum: 0.8858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0025 | Backhand: 0.1116 | Nenhum: 0.8859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0025 | Backhand: 0.1114 | Nenhum: 0.8861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Forehand: 0.0025 | Backhand: 0.1111 | Nenhum: 0.8864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Forehand: 0.0025 | Backhand: 0.1110 | Nenhum: 0.8865
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0025 | Backhand: 0.1108 | Nenhum: 0.8867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0025 | Backhand: 0.1106 | Nenhum: 0.8869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0025 | Backhand: 0.1103 | Nenhum: 0.8873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0024 | Backhand: 0.1100 | Nenhum: 0.8875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Forehand: 0.0024 | Backhand: 0.1103 | Nenhum: 0.8873
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0024 | Backhand: 0.1108 | Nenhum: 0.8868
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0024 | Backhand: 0.1115 | Nenhum: 0.8861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Forehand: 0.0024 | Backhand: 0.1125 | Nenhum: 0.8850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Forehand: 0.0024 | Backhand: 0.1136 | Nenhum: 0.8840
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0024 | Backhand: 0.1145 | Nenhum: 0.8830
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0024 | Backhand: 0.1151 | Nenhum: 0.8824
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Forehand: 0.0024 | Backhand: 0.1153 | Nenhum: 0.8823
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0024 | Backhand: 0.1149 | Nenhum: 0.8827
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0024 | Backhand: 0.1146 | Nenhum: 0.8830
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Forehand: 0.0024 | Backhand: 0.1143 | Nenhum: 0.8832
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0024 | Backhand: 0.1141 | Nenhum: 0.8835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0024 | Backhand: 0.1138 | Nenhum: 0.8838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0024 | Backhand: 0.1132 | Nenhum: 0.8843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0025 | Backhand: 0.1124 | Nenhum: 0.8851
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Forehand: 0.0025 | Backhand: 0.1117 | Nenhum: 0.8858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0025 | Backhand: 0.1105 | Nenhum: 0.8870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Forehand: 0.0025 | Backhand: 0.1086 | Nenhum: 0.8888
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Forehand: 0.0026 | Backhand: 0.1070 | Nenhum: 0.8904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0026 | Backhand: 0.1055 | Nenhum: 0.8919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0027 | Backhand: 0.1040 | Nenhum: 0.8933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Forehand: 0.0027 | Backhand: 0.1030 | Nenhum: 0.8943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Forehand: 0.0027 | Backhand: 0.1022 | Nenhum: 0.8951
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Forehand: 0.0028 | Backhand: 0.1017 | Nenhum: 0.8955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0028 | Backhand: 0.1016 | Nenhum: 0.8957
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0028 | Backhand: 0.1017 | Nenhum: 0.8955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0028 | Backhand: 0.1020 | Nenhum: 0.8952
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Forehand: 0.0028 | Backhand: 0.1025 | Nenhum: 0.8947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0027 | Backhand: 0.1031 | Nenhum: 0.8941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0027 | Backhand: 0.1039 | Nenhum: 0.8934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.1046 | Nenhum: 0.8926
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.1055 | Nenhum: 0.8919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.1065 | Nenhum: 0.8908
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0026 | Backhand: 0.1077 | Nenhum: 0.8897
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0026 | Backhand: 0.1090 | Nenhum: 0.8884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0026 | Backhand: 0.1096 | Nenhum: 0.8879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0025 | Backhand: 0.1105 | Nenhum: 0.8870
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0025 | Backhand: 0.1114 | Nenhum: 0.8861
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Forehand: 0.0025 | Backhand: 0.1122 | Nenhum: 0.8854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Forehand: 0.0024 | Backhand: 0.1128 | Nenhum: 0.8848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Forehand: 0.0024 | Backhand: 0.1132 | Nenhum: 0.8844
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Forehand: 0.0024 | Backhand: 0.1133 | Nenhum: 0.8842
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0024 | Backhand: 0.1135 | Nenhum: 0.8841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Forehand: 0.0024 | Backhand: 0.1128 | Nenhum: 0.8847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0025 | Backhand: 0.1120 | Nenhum: 0.8856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0025 | Backhand: 0.1108 | Nenhum: 0.8867
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0025 | Backhand: 0.1097 | Nenhum: 0.8878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0024 | Backhand: 0.1075 | Nenhum: 0.8901
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Forehand: 0.0025 | Backhand: 0.1045 | Nenhum: 0.8930
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Forehand: 0.0025 | Backhand: 0.1011 | Nenhum: 0.8964
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0026 | Backhand: 0.0986 | Nenhum: 0.8988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Forehand: 0.0026 | Backhand: 0.0968 | Nenhum: 0.9005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0027 | Backhand: 0.0958 | Nenhum: 0.9015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0027 | Backhand: 0.0954 | Nenhum: 0.9018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0028 | Backhand: 0.0954 | Nenhum: 0.9018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0028 | Backhand: 0.0958 | Nenhum: 0.9014
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Forehand: 0.0028 | Backhand: 0.0963 | Nenhum: 0.9009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0028 | Backhand: 0.0972 | Nenhum: 0.9000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Forehand: 0.0028 | Backhand: 0.0982 | Nenhum: 0.8990
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Forehand: 0.0029 | Backhand: 0.0991 | Nenhum: 0.8980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Forehand: 0.0029 | Backhand: 0.1000 | Nenhum: 0.8971
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Forehand: 0.0029 | Backhand: 0.1010 | Nenhum: 0.8961
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Forehand: 0.0029 | Backhand: 0.1024 | Nenhum: 0.8947
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0029 | Backhand: 0.1040 | Nenhum: 0.8931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0029 | Backhand: 0.1048 | Nenhum: 0.8922
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0029 | Backhand: 0.1065 | Nenhum: 0.8907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0028 | Backhand: 0.1082 | Nenhum: 0.8890
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Forehand: 0.0027 | Backhand: 0.1096 | Nenhum: 0.8876
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0027 | Backhand: 0.1109 | Nenhum: 0.8864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Forehand: 0.0026 | Backhand: 0.1117 | Nenhum: 0.8856
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Forehand: 0.0026 | Backhand: 0.1120 | Nenhum: 0.8854
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Forehand: 0.0027 | Backhand: 0.1109 | Nenhum: 0.8864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Forehand: 0.0047 | Backhand: 0.1073 | Nenhum: 0.8879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Forehand: 0.0118 | Backhand: 0.0801 | Nenhum: 0.9081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0285 | Backhand: 0.0550 | Nenhum: 0.9165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Forehand: 0.0230 | Backhand: 0.0595 | Nenhum: 0.9175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Forehand: 0.0111 | Backhand: 0.0784 | Nenhum: 0.9105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Forehand: 0.0029 | Backhand: 0.1038 | Nenhum: 0.8933
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Forehand: 0.0026 | Backhand: 0.1036 | Nenhum: 0.8938
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Forehand: 0.0026 | Backhand: 0.1026 | Nenhum: 0.8948
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Forehand: 0.0026 | Backhand: 0.1007 | Nenhum: 0.8967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Forehand: 0.0026 | Backhand: 0.0990 | Nenhum: 0.8984
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Forehand: 0.0026 | Backhand: 0.0978 | Nenhum: 0.8996
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Forehand: 0.0026 | Backhand: 0.0970 | Nenhum: 0.9004
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Forehand: 0.0026 | Backhand: 0.0961 | Nenhum: 0.9013
